# %%
import pandas as pd
import numpy as np
import pymc as pm   
import plotly.express as px

# %%
df_sales = pd.read_csv("new_product_launch_data.csv")

# %%
df_sales
# Out:
#            Date  Week     SKU    Brand  Price   ACV  Is_New_Product  \
# 0    2023-01-02     1  SKU_A1  Brand_A   1.96  0.97               0
# 1    2023-01-02     1  SKU_B1  Brand_B   1.77  0.96               0
# 2    2023-01-02     1  SKU_B2  Brand_B   2.03  0.97               0
# 3    2023-01-02     1  SKU_C1  Brand_C   2.21  0.84               0
# 4    2023-01-09     2  SKU_A1  Brand_A   1.90  0.89               0
# ..          ...   ...     ...      ...    ...   ...             ...
# 510  2024-12-23   104  SKU_A2  Brand_A   2.56  0.84               0
# 511  2024-12-23   104  SKU_B1  Brand_B   1.97  0.82               0
# 512  2024-12-23   104  SKU_B2  Brand_B   2.28  0.80               0
# 513  2024-12-23   104  SKU_C1  Brand_C   2.02  0.84               0
# 514  2024-12-23   104  SKU_A3  Brand_A   2.14  0.88               1
#
#      Post_Launch  Sales_Volume
# 0              0         27730
# 1              0         34366
# 2              0         16430
# ...

# %%
df_sales.groupby(['Brand','SKU'])['Sales_Volume'].sum()
# Out:
# Brand    SKU
# Brand_A  SKU_A1    2175829
#          SKU_A2     698615
#          SKU_A3     951471
# Brand_B  SKU_B1    2196568
#          SKU_B2    1085568
# Brand_C  SKU_C1    1175311
# Name: Sales_Volume, dtype: int64

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 515 entries, 2023-01-02 to 2024-12-23
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Week            515 non-null    int64
#  1   SKU             515 non-null    object
#  2   Brand           515 non-null    object
#  3   Price           515 non-null    float64
#  4   ACV             515 non-null    float64
#  5   Is_New_Product  515 non-null    int64
#  6   Post_Launch     515 non-null    int64
#  7   Sales_Volume    515 non-null    int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 36.2+ KB

# %%
df_sales['Date'] = pd.to_datetime(df_sales['Date'])

# %%
fig = px.line(df_sales, x='Date', y='Sales_Volume', color='SKU')
fig.show()

# %%
fig = px.line(df_sales, x='Date', y='Sales_Volume', color='Brand')
fig.show()

# %%
fig = px.line(df_sales, x='Date', y='Sales_Volume', color='Price')
fig.show()
